# %% [markdown]
# ## *Importing all the required libraries and functions*

# %%
import pandas as pd
from pymongo import MongoClient
import pymongo
import time
import numpy as np
import scipy.linalg
import tensorflow as tf
from copy import deepcopy
from threading import Lock
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report,confusion_matrix
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## *Load data*

# %%
t = pd.read_csv('cardio_train.csv', sep=';')
t.head()
t['age'] = (t['age'] / 365).astype('int')
t.drop('id', axis=1, inplace=True)
x = t.drop('cardio', axis=1)
y = t['active']
np.unique(y, return_counts=True)
y = pd.get_dummies(y) # OHE
t.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco
# 0   50       2     168    62.0    110     80            1     1      0     0  \
# 1   55       1     156    85.0    140     90            3     1      0     0
# 2   51       1     165    64.0    130     70            3     1      0     0
# 3   48       2     169    82.0    150    100            1     1      0     0
# 4   47       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %% [markdown]
# ## *Input datas are converted into JSON format and stored into MongoDBNoSQL database.*

# %%
# Read the semicolon-delimited CSV dataset using pandas
dataset_path = 'cardio_train.csv'
data = pd.read_csv(dataset_path, delimiter=';')

# Convert data to JSON format
data_json = data.to_dict(orient='records')

# MongoDB connection
def connect_to_mongodb():
    client = MongoClient('mongodb://localhost:27017/')
    db = client['heart_disease_database']
    collection = db['heart_failure_data']
    return collection

# Connect to MongoDB
collection = connect_to_mongodb()

# Insert data into MongoDB
collection.insert_many(data_json)
print("CSV converted to JSON.")
print(f"{len(data_json)} records inserted into MongoDB.")
# Out:
# CSV converted to JSON.
# 70000 records inserted into MongoDB.

# %% [markdown]
# ## *Retrieve and display the datas from mongodb*

# %%
# MongoDB connection
def connect_to_mongodb():
    client = MongoClient('mongodb://localhost:27017/')
    db = client['heart_disease_database']
    collection = db['heart_failure_data']
    return collection

# Connect to MongoDB
collection = connect_to_mongodb()

# Retrieve and display the first 5 records
limit = 5
for record in collection.find().limit(limit):
    print(record)

print(f"Displayed {limit} records.")
# Out:
# {'_id': ObjectId('64e32b4f60291ad11c2061c4'), 'id': 0, 'age': 18393, 'gender': 2, 'height': 168, 'weight': 62.0, 'ap_hi': 110, 'ap_lo': 80, 'cholesterol': 1, 'gluc': 1, 'smoke': 0, 'alco': 0, 'active': 1, 'cardio': 0}
# {'_id': ObjectId('64e32b4f60291ad11c2061c5'), 'id': 1, 'age': 20228, 'gender': 1, 'height': 156, 'weight': 85.0, 'ap_hi': 140, 'ap_lo': 90, 'cholesterol': 3, 'gluc': 1, 'smoke': 0, 'alco': 0, 'active': 1, 'cardio': 1}
# {'_id': ObjectId('64e32b4f60291ad11c2061c6'), 'id': 2, 'age': 18857, 'gender': 1, 'height': 165, 'weight': 64.0, 'ap_hi': 130, 'ap_lo': 70, 'cholesterol': 3, 'gluc': 1, 'smoke': 0, 'alco': 0, 'active': 0, 'cardio': 1}
# {'_id': ObjectId('64e32b4f60291ad11c2061c7'), 'id': 3, 'age': 17623, 'gender': 2, 'height': 169, 'weight': 82.0, 'ap_hi': 150, 'ap_lo': 100, 'cholesterol': 1, 'gluc': 1, 'smoke': 0, 'alco': 0, 'active': 1, 'cardio': 1}
# {'_id': ObjectId('64e32b4f60291ad11c2061c8'), 'id': 4, 'age': 17474, 'gender': 1, 'height': 156, 'weight': 56.0, 'ap_hi': 100, 'ap_lo': 60, 'cholesterol': 1, 'gluc': 1, 'smoke': 0, 'alco': 0, 'active': 0, 'cardio': 0}
# Displayed 5 records.

# %%
class UKF:
    def __init__(self, num_states, process_noise, initial_state, initial_covar, alpha, k, beta, iterate_function):
        """
        Initializes the unscented kalman filter
        :param num_states: int, the size of the state
        :param process_noise: the process noise covariance per unit time, should be num_states x num_states
        :param initial_state: initial values for the states, should be num_states x 1
        :param initial_covar: initial covariance matrix, should be num_states x num_states, typically large and diagonal
        :param alpha: UKF tuning parameter, determines spread of sigma points, typically a small positive value
        :param k: UKF tuning parameter, typically 0 or 3 - num_states
        :param beta: UKF tuning parameter, beta = 2 is ideal for gaussian distributions
        :param iterate_function: function that predicts the next state
                    takes in a num_states x 1 state and a float timestep
                    returns a num_states x 1 state
        """
        self.n_dim = int(num_states)
        self.n_sig = 1 + num_states * 2
        self.q = process_noise
        self.x = initial_state
        self.p = initial_covar
        self.beta = beta
        self.alpha = alpha
        self.k = k
        self.iterate = iterate_function

        self.lambd = pow(self.alpha, 2) * (self.n_dim + self.k) - self.n_dim

        self.covar_weights = np.zeros(self.n_sig)
        self.mean_weights = np.zeros(self.n_sig)

        self.covar_weights[0] = (self.lambd / (self.n_dim + self.lambd)) + (1 - pow(self.alpha, 2) + self.beta)
        self.mean_weights[0] = (self.lambd / (self.n_dim + self.lambd))

        for i in range(1, self.n_sig):
            self.covar_weights[i] = 1 / (2*(self.n_dim + self.lambd))
            self.mean_weights[i] = 1 / (2*(self.n_dim + self.lambd))

        self.sigmas = self.__get_sigmas()

        self.lock = Lock()

    def __get_sigmas(self):
        """generates sigma points"""
        ret = np.zeros((self.n_sig, self.n_dim))

        tmp_mat = (self.n_dim + self.lambd)*self.p

        # print spr_mat
        spr_mat = scipy.linalg.sqrtm(tmp_mat)

        ret[0] = self.x
        for i in range(self.n_dim):
            ret[i+1] = self.x + spr_mat[i]
            ret[i+1+self.n_dim] = self.x - spr_mat[i]

        return ret.T

    def update(self, states, data, r_matrix):
       
        self.lock.acquire()

        num_states = len(states)

        # create y, sigmas of just the states that are being updated
        sigmas_split = np.split(self.sigmas, self.n_dim)
        y = np.concatenate([sigmas_split[i] for i in states])

        # create y_mean, the mean of just the states that are being updated
        x_split = np.split(self.x, self.n_dim)
        y_mean = np.concatenate([x_split[i] for i in states])

        # differences in y from y mean
        y_diff = deepcopy(y)
        x_diff = deepcopy(self.sigmas)
        for i in range(self.n_sig):
            for j in range(num_states):
                y_diff[j][i] -= y_mean[j]
            for j in range(self.n_dim):
                x_diff[j][i] -= self.x[j]

        # covariance of measurement
        p_yy = np.zeros((num_states, num_states))
        for i, val in enumerate(np.array_split(y_diff, self.n_sig, 1)):
            p_yy += self.covar_weights[i] * val.dot(val.T)

        # add measurement noise
        p_yy += r_matrix

        # covariance of measurement with states
        p_xy = np.zeros((self.n_dim, num_states))
        for i, val in enumerate(zip(np.array_split(y_diff, self.n_sig, 1), np.array_split(x_diff, self.n_sig, 1))):
            p_xy += self.covar_weights[i] * val[1].dot(val[0].T)

        k = np.dot(p_xy, np.linalg.inv(p_yy))

        y_actual = data

        self.x += np.dot(k, (y_actual - y_mean))
        self.p -= np.dot(k, np.dot(p_yy, k.T))
        self.sigmas = self.__get_sigmas()

        self.lock.release()

# %%
# Connect to MongoDB
client = pymongo.MongoClient("localhost", 27017)
db = client["heart_disease_database"]
collection = db["heart_failure_data"]

# Retrieve data from MongoDB
documents = collection.find()
# Retrieve data from MongoDB
data_from_mongo = list(collection.find())

# %%
# Assume that each document has features and a label ('normal' or 'abnormal')
X = []  # Features
Y = []  # Labels

for document in data_from_mongo:
    features = [document["id"],
        document["age"],
        document["gender"],
        document["height"],
        document["weight"],
        document["ap_hi"],
        document["ap_lo"],document["cholesterol"],document["gluc"],document["smoke"],document["alco"],
        document["active"]]  # Add more features as needed
    label = 1 if document['cardio'] == 1 else 0
    
    X.append(features)
    Y.append(label)



# Convert lists to numpy arrays
X = np.array(X)
Y = np.array(Y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)

# Normalize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## **Interference-Tolerant Fast Convergence Zeroing Neural Network (ITFCZNN)**

# %%
# Define the ITFCZNN architecture
def itfcznn_model(input_shape, num_classes):
    model = tf.keras.models.Sequential([
    # Input Layer
    tf.keras.layers.Dense(units=x.shape[1], activation='relu', input_shape=(11,)),
    # Hidden Layer
    tf.keras.layers.Dense(units=30, activation='relu'),
    tf.keras.layers.Dropout(rate=.2),
    tf.keras.layers.Dense(units=40, activation='relu'),
    tf.keras.layers.Dropout(.3),
    tf.keras.layers.Dense(units=50, activation='relu'),
    tf.keras.layers.Dropout(.4),
    tf.keras.layers.Dense(units=40, activation='relu'),
    tf.keras.layers.Dropout(.3),
    tf.keras.layers.Dense(units=30, activation='relu'),
    tf.keras.layers.Dropout(.2),
#     tf.keras.layers.Dense(units=40, activation='relu'),
    # Output Layer
    tf.keras.layers.Dense(units=2, activation='softmax')
    ])
    return model

# Define input shape and number of classes
input_shape = (11,)
num_classes=2  
# Create the model
model = itfcznn_model(input_shape, num_classes)
    # Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(),
                       loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                       metrics=tf.keras.metrics.CategoricalAccuracy())

# Train the model
model.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=50)
# Out:
# Epoch 1/15
# 1050/1050 [==============================] - 14s 4ms/step - loss: 0.5630 - categorical_accuracy: 0.7959 - val_loss: 0.4961 - val_categorical_accuracy: 0.8039
# Epoch 2/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.4983 - categorical_accuracy: 0.8031 - val_loss: 0.4863 - val_categorical_accuracy: 0.8039
# Epoch 3/15
# 1050/1050 [==============================] - 4s 3ms/step - loss: 0.2606 - categorical_accuracy: 0.8875 - val_loss: 0.0293 - val_categorical_accuracy: 0.9887
# Epoch 4/15
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.0283 - categorical_accuracy: 0.9928 - val_loss: 0.0137 - val_categorical_accuracy: 0.9953
# Epoch 5/15
# 1050/1050 [==============================] - 5s 5ms/step - loss: 0.0197 - categorical_accuracy: 0.9940 - val_loss: 0.0118 - val_categorical_accuracy: 0.9961
# Epoch 6/15
# 1050/1050 [==============================] - 5s 5ms/step - loss: 0.0181 - categorical_accuracy: 0.9956 - val_loss: 0.0135 - val_categorical_accuracy: 0.9955
# Epoch 7/15
# 1050/1050 [==============================] - 9s 8ms/step - loss: 0.0130 - categorical_accuracy: 0.9962 - val_loss: 0.0099 - val_categorical_accuracy: 0.9963
# Epoch 8/15
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.0353 - categorical_accuracy: 0.9921 - val_loss: 0.0114 - val_categorical_accuracy: 0.9959
# Epoch 9/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0174 - categorical_accuracy: 0.9956 - val_loss: 0.0098 - val_categorical_accuracy: 0.9962
# Epoch 10/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0142 - categorical_accuracy: 0.9962 - val_loss: 0.0092 - val_categorical_accuracy: 0.9965
# Epoch 11/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0101 - categorical_accuracy: 0.9967 - val_loss: 0.0086 - val_categorical_accuracy: 0.9966
# Epoch 12/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0186 - categorical_accuracy: 0.9956 - val_loss: 0.0088 - val_categorical_accuracy: 0.9965
# Epoch 13/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0129 - categorical_accuracy: 0.9965 - val_loss: 0.0089 - val_categorical_accuracy: 0.9965
# Epoch 14/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0263 - categorical_accuracy: 0.9929 - val_loss: 0.0087 - val_categorical_accuracy: 0.9966
# Epoch 15/15
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.0158 - categorical_accuracy: 0.9955 - val_loss: 0.0092 - val_categorical_accuracy: 0.9966

# %% [markdown]
# ## *Prediction*

# %%
# Generate predictions
X_train, x_test, y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
itfcznn_model = tf.keras.Sequential([
           tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
           tf.keras.layers.Dense(32, activation='relu'),
         tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
        ])
predictions = itfcznn_model.predict(X_test_scaled)

# Apply threshold for binary classification
threshold = 0.5
binary_predictions = (predictions < threshold).astype(int)

# Map binary predictions to labels
class_mapping = {1: 'presence', 0: 'absence'}
predicted_labels = [class_mapping[int(prediction)] for prediction in binary_predictions]

# Assuming each prediction corresponds to a document with an ID
document_ids = x_test[:, 0]  # Assuming 'id' is the first feature in your X array

# Create a list of dictionaries with ID and prediction result
results = [{'id': int(document_id), 'prediction': label} for document_id, label in zip(document_ids, predicted_labels)]
results
# Out:
# 547/547 [==============================] - 1s 1ms/step
# [{'id': 66728, 'prediction': 'presence'},
#  {'id': 69098, 'prediction': 'presence'},
#  {'id': 59185, 'prediction': 'presence'},
#  {'id': 49288, 'prediction': 'presence'},
#  {'id': 62481, 'prediction': 'presence'},
#  {'id': 16605, 'prediction': 'presence'},
#  {'id': 35209, 'prediction': 'presence'},
#  {'id': 32015, 'prediction': 'absence'},
#  {'id': 1307, 'prediction': 'absence'},
#  {'id': 80437, 'prediction': 'presence'},
#  {'id': 37048, 'prediction': 'presence'},
#  {'id': 45001, 'prediction': 'presence'},
#  {'id': 6624, 'prediction': 'presence'},
#  {'id': 24101, 'prediction': 'absence'},
#  {'id': 5972, 'prediction': 'presence'},
#  {'id': 93793, 'prediction': 'absence'},
#  {'id': 5352, 'prediction': 'presence'},
#  {'id': 44803, 'prediction': 'presence'},
#  {'id': 90475, 'prediction': 'presence'},
#  {'id': 14122, 'prediction': 'presence'},
#  {'id': 58765, 'prediction': 'presence'},
#  {'id': 4197, 'prediction': 'absence'},
#  {'id': 92516, 'prediction': 'presence'},
#  {'id': 94854, 'prediction': 'absence'},
#  {'id': 39896, 'prediction': 'presence'},
#  {'id': 73282, 'prediction': 'presence'},
#  {'id': 53139, 'prediction': 'presence'},
#  {'id': 19475, 'prediction': 'presence'},
#  {'id': 5322, 'prediction': 'presence'},
#  {'id': 83138, 'prediction': 'presence'},
#  {'id': 74599, 'prediction': 'presence'},
#  {'id': 92652, 'prediction': 'absence'},
#  {'id': 95767, 'prediction': 'presence'},
#  {'id': 46174, 'prediction': 'absence'},
#  {'id': 5147, 'prediction': 'presence'},
#  {'id': 70916, 'prediction': 'presence'},
#  {'id': 26482, 'prediction': 'presence'},
#  {'id': 69665, 'prediction': 'absence'},
#  {'id': 173, 'prediction': 'presence'},
#  {'id': 96889, 'prediction': 'absence'},
#  {'id': 16946, 'prediction': 'absence'},
#  {'id': 42403, 'prediction': 'presence'},
#  {'id': 22171, 'prediction': 'absence'},
#  {'id': 75947, 'prediction': 'presence'},
#  {'id': 48627, 'prediction': 'absence'},
#  {'id': 85168, 'prediction': 'absence'},
#  {'id': 48690, 'prediction': 'presence'},
#  {'id': 17128, 'prediction': 'absence'},
#  {'id': 30205, 'prediction': 'presence'},
#  {'id': 4626, 'prediction': 'presence'},
#  {'id': 84407, 'prediction': 'presence'},
#  {'id': 89072, 'prediction': 'presence'},
#  {'id': 4428, 'prediction': 'presence'},
#  {'id': 37164, 'prediction': 'presence'},
#  {'id': 88625, 'prediction': 'absence'},
#  {'id': 94643, 'prediction': 'absence'},
#  {'id': 73961, 'prediction': 'absence'},
#  {'id': 60289, 'prediction': 'presence'},
#  {'id': 10694, 'prediction': 'presence'},
#  {'id': 72113, 'prediction': 'presence'},
#  {'id': 56739, 'prediction': 'presence'},
#  {'id': 80060, 'prediction': 'absence'},
#  {'id': 33134, 'prediction': 'presence'},
#  {'id': 96406, 'prediction': 'absence'},
#  {'id': 59027, 'prediction': 'presence'},
#  {'id': 49423, 'prediction': 'presence'},
#  {'id': 50176, 'prediction': 'presence'},
#  {'id': 5797, 'prediction': 'presence'},
#  {'id': 48664, 'prediction': 'presence'},
#  {'id': 8620, 'prediction': 'presence'},
#  {'id': 77200, 'prediction': 'presence'},
#  {'id': 68907, 'prediction': 'absence'},
#  {'id': 8232, 'prediction': 'absence'},
#  {'id': 27827, 'prediction': 'presence'},
#  {'id': 75376, 'prediction': 'presence'},
#  {'id': 18099, 'prediction': 'presence'},
#  {'id': 52327, 'prediction': 'presence'},
#  {'id': 16644, 'prediction': 'presence'},
#  {'id': 46194, 'prediction': 'presence'},
#  {'id': 45967, 'prediction': 'presence'},
#  {'id': 94724, 'prediction': 'absence'},
#  {'id': 53558, 'prediction': 'presence'},
#  {'id': 94422, 'prediction': 'presence'},
#  {'id': 69205, 'prediction': 'presence'},
#  {'id': 77797, 'prediction': 'presence'},
#  {'id': 68853, 'prediction': 'presence'},
#  {'id': 31902, 'prediction': 'presence'},
#  {'id': 48463, 'prediction': 'absence'},
#  {'id': 12483, 'prediction': 'presence'},
#  {'id': 53079, 'prediction': 'presence'},
#  {'id': 95864, 'prediction': 'presence'},
#  {'id': 72086, 'prediction': 'presence'},
#  {'id': 94236, 'prediction': 'absence'},
#  {'id': 74601, 'prediction': 'presence'},
#  {'id': 18597, 'prediction': 'presence'},
#  {'id': 29923, 'prediction': 'absence'},
#  {'id': 81655, 'prediction': 'absence'},
#  {'id': 67066, 'prediction': 'absence'},
#  {'id': 82998, 'prediction': 'presence'},
#  {'id': 38424, 'prediction': 'presence'},
#  {'id': 72026, 'prediction': 'presence'},
#  {'id': 8805, 'prediction': 'presence'},
#  {'id': 19262, 'prediction': 'presence'},
#  {'id': 13645, 'prediction': 'presence'},
#  {'id': 172, 'prediction': 'absence'},
#  {'id': 9250, 'prediction': 'absence'},
#  {'id': 5844, 'prediction': 'absence'},
#  {'id': 61123, 'prediction': 'presence'},
#  {'id': 34069, 'prediction': 'presence'},
#  {'id': 64095, 'prediction': 'presence'},
#  {'id': 59422, 'prediction': 'presence'},
#  {'id': 61645, 'prediction': 'presence'},
#  {'id': 44661, 'prediction': 'presence'},
#  {'id': 31673, 'prediction': 'presence'},
#  {'id': 60454, 'prediction': 'presence'},
#  {'id': 92797, 'prediction': 'presence'},
#  {'id': 37701, 'prediction': 'presence'},
#  {'id': 52532, 'prediction': 'absence'},
#  {'id': 79723, 'prediction': 'absence'},
#  {'id': 80661, 'prediction': 'absence'},
#  {'id': 36713, 'prediction': 'presence'},
#  {'id': 48573, 'prediction': 'presence'},
#  {'id': 29711, 'prediction': 'presence'},
#  {'id': 55536, 'prediction': 'absence'},
#  {'id': 73933, 'prediction': 'presence'},
#  {'id': 32532, 'prediction': 'presence'},
#  {'id': 40437, 'prediction': 'presence'},
#  {'id': 10382, 'prediction': 'presence'},
#  {'id': 97656, 'prediction': 'presence'},
#  {'id': 44275, 'prediction': 'presence'},
#  {'id': 42944, 'prediction': 'absence'},
#  {'id': 83635, 'prediction': 'absence'},
#  {'id': 93022, 'prediction': 'absence'},
#  {'id': 8410, 'prediction': 'presence'},
#  {'id': 37010, 'prediction': 'presence'},
#  {'id': 44931, 'prediction': 'presence'},
#  {'id': 5997, 'prediction': 'presence'},
#  {'id': 49345, 'prediction': 'presence'},
#  {'id': 64222, 'prediction': 'presence'},
#  {'id': 94949, 'prediction': 'absence'},
#  {'id': 36733, 'prediction': 'presence'},
#  {'id': 15488, 'prediction': 'presence'},
#  {'id': 9455, 'prediction': 'presence'},
#  {'id': 52607, 'prediction': 'presence'},
#  {'id': 63683, 'prediction': 'absence'},
#  {'id': 90928, 'prediction': 'absence'},
#  {'id': 13924, 'prediction': 'presence'},
#  {'id': 96736, 'prediction': 'presence'},
#  {'id': 64952, 'prediction': 'presence'},
#  {'id': 53857, 'prediction': 'presence'},
#  {'id': 60808, 'prediction': 'presence'},
#  {'id': 45885, 'prediction': 'presence'},
#  {'id': 50760, 'prediction': 'presence'},
#  {'id': 46239, 'prediction': 'absence'},
#  {'id': 42463, 'prediction': 'presence'},
#  {'id': 94138, 'prediction': 'absence'},
#  {'id': 32345, 'prediction': 'presence'},
#  {'id': 65656, 'prediction': 'absence'},
#  {'id': 88242, 'prediction': 'presence'},
#  {'id': 2839, 'prediction': 'presence'},
#  {'id': 30605, 'prediction': 'presence'},
#  {'id': 24420, 'prediction': 'presence'},
#  {'id': 75703, 'prediction': 'absence'},
#  {'id': 84717, 'prediction': 'presence'},
#  {'id': 9033, 'prediction': 'absence'},
#  {'id': 76696, 'prediction': 'presence'},
#  {'id': 24713, 'prediction': 'absence'},
#  {'id': 75034, 'prediction': 'presence'},
#  {'id': 42140, 'prediction': 'presence'},
#  {'id': 71106, 'prediction': 'presence'},
#  {'id': 63869, 'prediction': 'presence'},
#  {'id': 96165, 'prediction': 'presence'},
#  {'id': 22422, 'prediction': 'presence'},
#  {'id': 33217, 'prediction': 'absence'},
#  {'id': 32144, 'prediction': 'absence'},
#  {'id': 32568, 'prediction': 'presence'},
#  {'id': 93447, 'prediction': 'presence'},
#  {'id': 64764, 'prediction': 'presence'},
#  {'id': 22470, 'prediction': 'presence'},
#  {'id': 73321, 'prediction': 'presence'},
#  {'id': 8117, 'prediction': 'presence'},
#  {'id': 3055, 'prediction': 'absence'},
#  {'id': 17720, 'prediction': 'presence'},
#  {'id': 14167, 'prediction': 'presence'},
#  {'id': 46482, 'prediction': 'absence'},
#  {'id': 42906, 'prediction': 'presence'},
#  {'id': 62126, 'prediction': 'presence'},
#  {'id': 25118, 'prediction': 'presence'},
#  {'id': 17252, 'prediction': 'absence'},
#  {'id': 39123, 'prediction': 'absence'},
#  {'id': 93820, 'prediction': 'presence'},
#  {'id': 70337, 'prediction': 'presence'},
#  {'id': 24485, 'prediction': 'presence'},
#  {'id': 45400, 'prediction': 'presence'},
#  {'id': 74569, 'prediction': 'presence'},
#  {'id': 84439, 'prediction': 'presence'},
#  {'id': 27020, 'prediction': 'presence'},
#  {'id': 79712, 'prediction': 'presence'},
#  {'id': 93193, 'prediction': 'presence'},
#  {'id': 11940, 'prediction': 'presence'},
#  {'id': 56660, 'prediction': 'presence'},
#  {'id': 38656, 'prediction': 'presence'},
#  {'id': 72167, 'prediction': 'absence'},
#  {'id': 64828, 'prediction': 'presence'},
#  {'id': 24552, 'prediction': 'presence'},
#  {'id': 63495, 'prediction': 'presence'},
#  {'id': 34240, 'prediction': 'presence'},
#  {'id': 34019, 'prediction': 'presence'},
#  {'id': 45778, 'prediction': 'presence'},
#  {'id': 67823, 'prediction': 'presence'},
#  {'id': 8790, 'prediction': 'presence'},
#  {'id': 21289, 'prediction': 'presence'},
#  {'id': 67184, 'prediction': 'absence'},
#  {'id': 66720, 'prediction': 'presence'},
#  {'id': 47021, 'prediction': 'absence'},
#  {'id': 90754, 'prediction': 'presence'},
#  {'id': 24267, 'prediction': 'presence'},
#  {'id': 68334, 'prediction': 'presence'},
#  {'id': 91488, 'prediction': 'presence'},
#  {'id': 9518, 'prediction': 'presence'},
#  {'id': 239, 'prediction': 'presence'},
#  {'id': 81799, 'prediction': 'presence'},
#  {'id': 78159, 'prediction': 'absence'},
#  {'id': 25192, 'prediction': 'presence'},
#  {'id': 19977, 'prediction': 'presence'},
#  {'id': 39234, 'prediction': 'presence'},
#  {'id': 15260, 'prediction': 'absence'},
#  {'id': 6385, 'prediction': 'presence'},
#  {'id': 73818, 'prediction': 'absence'},
#  {'id': 29297, 'prediction': 'presence'},
#  {'id': 43083, 'prediction': 'absence'},
#  {'id': 13545, 'prediction': 'presence'},
#  {'id': 57353, 'prediction': 'absence'},
#  {'id': 58434, 'prediction': 'presence'},
#  {'id': 68742, 'prediction': 'absence'},
#  {'id': 75711, 'prediction': 'presence'},
#  {'id': 720, 'prediction': 'absence'},
#  {'id': 44317, 'prediction': 'presence'},
#  {'id': 80323, 'prediction': 'presence'},
#  {'id': 19835, 'prediction': 'presence'},
#  {'id': 7296, 'prediction': 'presence'},
#  {'id': 30640, 'prediction': 'presence'},
#  {'id': 2371, 'prediction': 'absence'},
#  {'id': 57799, 'prediction': 'presence'},
#  {'id': 61557, 'prediction': 'presence'},
#  {'id': 19700, 'prediction': 'absence'},
#  {'id': 99006, 'prediction': 'presence'},
#  {'id': 48721, 'prediction': 'presence'},
#  {'id': 68468, 'prediction': 'presence'},
#  {'id': 44826, 'prediction': 'presence'},
#  {'id': 37435, 'prediction': 'presence'},
#  {'id': 613, 'prediction': 'presence'},
#  {'id': 45678, 'prediction': 'absence'},
#  {'id': 67957, 'prediction': 'absence'},
#  {'id': 43588, 'prediction': 'presence'},
#  {'id': 88122, 'prediction': 'presence'},
#  {'id': 91664, 'prediction': 'presence'},
#  {'id': 67779, 'prediction': 'presence'},
#  {'id': 88380, 'prediction': 'presence'},
#  {'id': 27490, 'prediction': 'presence'},
#  {'id': 87102, 'prediction': 'presence'},
#  {'id': 53752, 'prediction': 'presence'},
#  {'id': 96825, 'prediction': 'presence'},
#  {'id': 16107, 'prediction': 'absence'},
#  {'id': 17855, 'prediction': 'absence'},
#  {'id': 50455, 'prediction': 'presence'},
#  {'id': 79502, 'prediction': 'presence'},
#  {'id': 67533, 'prediction': 'presence'},
#  {'id': 60591, 'prediction': 'presence'},
#  {'id': 30221, 'prediction': 'presence'},
#  {'id': 37324, 'prediction': 'presence'},
#  {'id': 45607, 'prediction': 'presence'},
#  {'id': 71527, 'prediction': 'presence'},
#  {'id': 55843, 'prediction': 'presence'},
#  {'id': 38180, 'prediction': 'presence'},
#  {'id': 92154, 'prediction': 'presence'},
#  {'id': 47972, 'prediction': 'presence'},
#  {'id': 59634, 'prediction': 'presence'},
#  {'id': 79568, 'prediction': 'presence'},
#  {'id': 90673, 'prediction': 'presence'},
#  {'id': 67206, 'prediction': 'presence'},
#  {'id': 81875, 'prediction': 'presence'},
#  {'id': 54293, 'prediction': 'presence'},
#  {'id': 28170, 'prediction': 'presence'},
#  {'id': 75813, 'prediction': 'absence'},
#  {'id': 74802, 'prediction': 'presence'},
#  {'id': 20956, 'prediction': 'absence'},
#  {'id': 49211, 'prediction': 'absence'},
#  {'id': 56811, 'prediction': 'presence'},
#  {'id': 68972, 'prediction': 'presence'},
#  {'id': 63111, 'prediction': 'absence'},
#  {'id': 54898, 'prediction': 'presence'},
#  {'id': 81136, 'prediction': 'presence'},
#  {'id': 68382, 'prediction': 'presence'},
#  {'id': 29950, 'prediction': 'presence'},
#  {'id': 45693, 'prediction': 'presence'},
#  {'id': 91352, 'prediction': 'absence'},
#  {'id': 15700, 'prediction': 'absence'},
#  {'id': 84204, 'prediction': 'presence'},
#  {'id': 12508, 'prediction': 'presence'},
#  {'id': 69860, 'prediction': 'presence'},
#  {'id': 33862, 'prediction': 'presence'},
#  {'id': 1696, 'prediction': 'presence'},
#  {'id': 88076, 'prediction': 'presence'},
#  {'id': 18951, 'prediction': 'presence'},
#  {'id': 46564, 'prediction': 'presence'},
#  {'id': 49466, 'prediction': 'absence'},
#  {'id': 70950, 'prediction': 'absence'},
#  {'id': 902, 'prediction': 'presence'},
#  {'id': 80979, 'prediction': 'absence'},
#  {'id': 8521, 'prediction': 'presence'},
#  {'id': 95267, 'prediction': 'presence'},
#  {'id': 62675, 'prediction': 'presence'},
#  {'id': 53975, 'prediction': 'presence'},
#  {'id': 85034, 'prediction': 'absence'},
#  {'id': 20402, 'prediction': 'absence'},
#  {'id': 29562, 'prediction': 'presence'},
#  {'id': 31299, 'prediction': 'presence'},
#  {'id': 38435, 'prediction': 'absence'},
#  {'id': 93374, 'prediction': 'absence'},
#  {'id': 48270, 'prediction': 'absence'},
#  {'id': 75608, 'prediction': 'presence'},
#  {'id': 57546, 'prediction': 'presence'},
#  {'id': 19234, 'prediction': 'presence'},
#  {'id': 47503, 'prediction': 'presence'},
#  {'id': 22075, 'prediction': 'presence'},
#  {'id': 47345, 'prediction': 'presence'},
#  {'id': 76718, 'prediction': 'presence'},
#  {'id': 51248, 'prediction': 'presence'},
#  {'id': 51435, 'prediction': 'presence'},
#  {'id': 70635, 'prediction': 'presence'},
#  {'id': 39147, 'prediction': 'presence'},
#  {'id': 31473, 'prediction': 'presence'},
#  {'id': 82259, 'prediction': 'presence'},
#  {'id': 72440, 'prediction': 'presence'},
#  {'id': 74572, 'prediction': 'presence'},
#  {'id': 25899, 'prediction': 'presence'},
#  {'id': 68924, 'prediction': 'presence'},
#  {'id': 26267, 'prediction': 'presence'},
#  {'id': 58911, 'prediction': 'absence'},
#  {'id': 63150, 'prediction': 'presence'},
#  {'id': 96669, 'prediction': 'presence'},
#  {'id': 47390, 'prediction': 'presence'},
#  {'id': 26017, 'prediction': 'presence'},
#  {'id': 70374, 'prediction': 'presence'},
#  {'id': 79334, 'prediction': 'presence'},
#  {'id': 56380, 'prediction': 'presence'},
#  {'id': 28075, 'prediction': 'presence'},
#  {'id': 47767, 'prediction': 'presence'},
#  {'id': 91152, 'prediction': 'presence'},
#  {'id': 72752, 'prediction': 'presence'},
#  {'id': 41681, 'prediction': 'presence'},
#  {'id': 13982, 'prediction': 'presence'},
#  {'id': 9147, 'prediction': 'absence'},
#  {'id': 38273, 'prediction': 'absence'},
#  {'id': 49583, 'prediction': 'presence'},
#  {'id': 27508, 'prediction': 'presence'},
#  {'id': 63353, 'prediction': 'presence'},
#  {'id': 38050, 'prediction': 'presence'},
#  {'id': 74811, 'prediction': 'presence'},
#  {'id': 65634, 'prediction': 'presence'},
#  {'id': 14391, 'prediction': 'presence'},
#  {'id': 79733, 'prediction': 'absence'},
#  {'id': 82041, 'prediction': 'presence'},
#  {'id': 15599, 'prediction': 'presence'},
#  {'id': 6906, 'prediction': 'absence'},
#  {'id': 44088, 'prediction': 'presence'},
#  {'id': 67566, 'prediction': 'absence'},
#  {'id': 60975, 'prediction': 'presence'},
#  {'id': 74731, 'prediction': 'presence'},
#  {'id': 9517, 'prediction': 'presence'},
#  {'id': 86074, 'prediction': 'presence'},
#  {'id': 29350, 'prediction': 'presence'},
#  {'id': 3296, 'prediction': 'presence'},
#  {'id': 18595, 'prediction': 'presence'},
#  {'id': 69674, 'prediction': 'presence'},
#  {'id': 54476, 'prediction': 'presence'},
#  {'id': 25782, 'prediction': 'presence'},
#  {'id': 54773, 'prediction': 'absence'},
#  {'id': 11999, 'prediction': 'presence'},
#  {'id': 67946, 'prediction': 'presence'},
#  {'id': 73689, 'prediction': 'absence'},
#  {'id': 10158, 'prediction': 'absence'},
#  {'id': 59736, 'prediction': 'presence'},
#  {'id': 40696, 'prediction': 'presence'},
#  {'id': 44540, 'prediction': 'presence'},
#  {'id': 69135, 'prediction': 'presence'},
#  {'id': 11757, 'prediction': 'presence'},
#  {'id': 62407, 'prediction': 'presence'},
#  {'id': 49240, 'prediction': 'absence'},
#  {'id': 52785, 'prediction': 'presence'},
#  {'id': 25490, 'prediction': 'presence'},
#  {'id': 90398, 'prediction': 'presence'},
#  {'id': 68823, 'prediction': 'presence'},
#  {'id': 37968, 'prediction': 'presence'},
#  {'id': 43803, 'prediction': 'presence'},
#  {'id': 56668, 'prediction': 'presence'},
#  {'id': 21414, 'prediction': 'absence'},
#  {'id': 10588, 'prediction': 'absence'},
#  {'id': 88665, 'prediction': 'presence'},
#  {'id': 38271, 'prediction': 'absence'},
#  {'id': 54817, 'prediction': 'presence'},
#  {'id': 97459, 'prediction': 'presence'},
#  {'id': 85939, 'prediction': 'presence'},
#  {'id': 45855, 'prediction': 'absence'},
#  {'id': 12398, 'prediction': 'presence'},
#  {'id': 91929, 'prediction': 'presence'},
#  {'id': 52585, 'prediction': 'absence'},
#  {'id': 95040, 'prediction': 'presence'},
#  {'id': 61115, 'prediction': 'presence'},
#  {'id': 87190, 'prediction': 'presence'},
#  {'id': 6533, 'prediction': 'presence'},
#  {'id': 29499, 'prediction': 'presence'},
#  {'id': 35974, 'prediction': 'absence'},
#  {'id': 60241, 'prediction': 'presence'},
#  {'id': 51163, 'prediction': 'presence'},
#  {'id': 4706, 'prediction': 'presence'},
#  {'id': 94810, 'prediction': 'presence'},
#  {'id': 91087, 'prediction': 'presence'},
#  {'id': 38732, 'prediction': 'presence'},
#  {'id': 20726, 'prediction': 'presence'},
#  {'id': 73980, 'prediction': 'presence'},
#  {'id': 48784, 'prediction': 'presence'},
#  {'id': 65150, 'prediction': 'presence'},
#  {'id': 27904, 'prediction': 'presence'},
#  {'id': 57192, 'prediction': 'presence'},
#  {'id': 27131, 'prediction': 'absence'},
#  {'id': 28622, 'prediction': 'presence'},
#  {'id': 31145, 'prediction': 'presence'},
#  {'id': 26902, 'prediction': 'presence'},
#  {'id': 82684, 'prediction': 'presence'},
#  {'id': 21531, 'prediction': 'presence'},
#  {'id': 69647, 'prediction': 'presence'},
#  {'id': 31210, 'prediction': 'absence'},
#  {'id': 99934, 'prediction': 'absence'},
#  {'id': 20142, 'prediction': 'absence'},
#  {'id': 27539, 'prediction': 'presence'},
#  {'id': 43276, 'prediction': 'absence'},
#  {'id': 73926, 'prediction': 'presence'},
#  {'id': 12140, 'prediction': 'presence'},
#  {'id': 46232, 'prediction': 'presence'},
#  {'id': 74911, 'prediction': 'presence'},
#  {'id': 83100, 'prediction': 'presence'},
#  {'id': 31241, 'prediction': 'presence'},
#  {'id': 66360, 'prediction': 'absence'},
#  {'id': 8046, 'prediction': 'presence'},
#  {'id': 53076, 'prediction': 'absence'},
#  {'id': 87560, 'prediction': 'presence'},
#  {'id': 17287, 'prediction': 'absence'},
#  {'id': 76711, 'prediction': 'presence'},
#  {'id': 88611, 'prediction': 'absence'},
#  {'id': 7252, 'prediction': 'presence'},
#  {'id': 10146, 'prediction': 'presence'},
#  {'id': 40932, 'prediction': 'presence'},
#  {'id': 12132, 'prediction': 'presence'},
#  {'id': 84917, 'prediction': 'presence'},
#  {'id': 29694, 'prediction': 'presence'},
#  {'id': 87385, 'prediction': 'presence'},
#  {'id': 11054, 'prediction': 'presence'},
#  {'id': 30588, 'prediction': 'presence'},
#  {'id': 7771, 'prediction': 'presence'},
#  {'id': 83392, 'prediction': 'presence'},
#  {'id': 44252, 'prediction': 'presence'},
#  {'id': 71140, 'prediction': 'presence'},
#  {'id': 34846, 'prediction': 'presence'},
#  {'id': 66522, 'prediction': 'presence'},
#  {'id': 36839, 'prediction': 'presence'},
#  {'id': 70911, 'prediction': 'presence'},
#  {'id': 90798, 'prediction': 'absence'},
#  {'id': 18724, 'prediction': 'presence'},
#  {'id': 48980, 'prediction': 'presence'},
#  {'id': 89416, 'prediction': 'presence'},
#  {'id': 39424, 'prediction': 'absence'},
#  {'id': 83002, 'prediction': 'presence'},
#  {'id': 28146, 'prediction': 'presence'},
#  {'id': 27535, 'prediction': 'presence'},
#  {'id': 72923, 'prediction': 'absence'},
#  {'id': 22574, 'prediction': 'presence'},
#  {'id': 15505, 'prediction': 'absence'},
#  {'id': 98687, 'prediction': 'presence'},
#  {'id': 984, 'prediction': 'presence'},
#  {'id': 17690, 'prediction': 'presence'},
#  {'id': 2028, 'prediction': 'absence'},
#  {'id': 36025, 'prediction': 'absence'},
#  {'id': 43336, 'prediction': 'absence'},
#  {'id': 64440, 'prediction': 'presence'},
#  {'id': 4184, 'prediction': 'presence'},
#  {'id': 77360, 'prediction': 'presence'},
#  {'id': 59519, 'prediction': 'presence'},
#  {'id': 2623, 'prediction': 'absence'},
#  {'id': 61106, 'prediction': 'presence'},
#  {'id': 49206, 'prediction': 'presence'},
#  {'id': 9057, 'prediction': 'absence'},
#  {'id': 53595, 'prediction': 'presence'},
#  {'id': 64289, 'prediction': 'presence'},
#  {'id': 59009, 'prediction': 'presence'},
#  {'id': 67488, 'prediction': 'presence'},
#  {'id': 19693, 'prediction': 'presence'},
#  {'id': 21476, 'prediction': 'presence'},
#  {'id': 60247, 'prediction': 'presence'},
#  {'id': 19080, 'prediction': 'absence'},
#  {'id': 85130, 'prediction': 'presence'},
#  {'id': 71467, 'prediction': 'presence'},
#  {'id': 1744, 'prediction': 'presence'},
#  {'id': 67577, 'prediction': 'absence'},
#  {'id': 23911, 'prediction': 'absence'},
#  {'id': 54869, 'prediction': 'presence'},
#  {'id': 83353, 'prediction': 'presence'},
#  {'id': 14131, 'prediction': 'presence'},
#  {'id': 64556, 'prediction': 'presence'},
#  {'id': 21569, 'prediction': 'presence'},
#  {'id': 54903, 'prediction': 'presence'},
#  {'id': 66437, 'prediction': 'presence'},
#  {'id': 54164, 'prediction': 'presence'},
#  {'id': 23033, 'prediction': 'presence'},
#  {'id': 57034, 'prediction': 'presence'},
#  {'id': 26046, 'prediction': 'absence'},
#  {'id': 57560, 'prediction': 'presence'},
#  {'id': 48354, 'prediction': 'presence'},
#  {'id': 87198, 'prediction': 'presence'},
#  {'id': 41423, 'prediction': 'presence'},
#  {'id': 97063, 'prediction': 'presence'},
#  {'id': 33404, 'prediction': 'absence'},
#  {'id': 69758, 'prediction': 'presence'},
#  {'id': 62402, 'prediction': 'presence'},
#  {'id': 62366, 'prediction': 'presence'},
#  {'id': 3325, 'prediction': 'presence'},
#  {'id': 98369, 'prediction': 'absence'},
#  {'id': 70737, 'prediction': 'presence'},
#  {'id': 96007, 'prediction': 'absence'},
#  {'id': 51269, 'prediction': 'presence'},
#  {'id': 68987, 'prediction': 'absence'},
#  {'id': 57668, 'prediction': 'presence'},
#  {'id': 14765, 'prediction': 'presence'},
#  {'id': 78669, 'prediction': 'presence'},
#  {'id': 59572, 'prediction': 'presence'},
#  {'id': 8311, 'prediction': 'presence'},
#  {'id': 23091, 'prediction': 'presence'},
#  {'id': 4870, 'prediction': 'presence'},
#  {'id': 84318, 'prediction': 'presence'},
#  {'id': 98115, 'prediction': 'presence'},
#  {'id': 30185, 'prediction': 'presence'},
#  {'id': 15500, 'prediction': 'presence'},
#  {'id': 40006, 'prediction': 'presence'},
#  {'id': 97393, 'prediction': 'presence'},
#  {'id': 94189, 'prediction': 'presence'},
#  {'id': 20514, 'prediction': 'presence'},
#  {'id': 56781, 'prediction': 'presence'},
#  {'id': 89002, 'prediction': 'presence'},
#  {'id': 23736, 'prediction': 'presence'},
#  {'id': 13054, 'prediction': 'presence'},
#  {'id': 95436, 'prediction': 'presence'},
#  {'id': 32832, 'prediction': 'presence'},
#  {'id': 25788, 'prediction': 'presence'},
#  {'id': 38119, 'prediction': 'presence'},
#  {'id': 76049, 'prediction': 'absence'},
#  {'id': 58036, 'prediction': 'presence'},
#  {'id': 84960, 'prediction': 'presence'},
#  {'id': 77909, 'prediction': 'absence'},
#  {'id': 99670, 'prediction': 'absence'},
#  {'id': 77375, 'prediction': 'presence'},
#  {'id': 25125, 'prediction': 'absence'},
#  {'id': 24719, 'prediction': 'presence'},
#  {'id': 64734, 'prediction': 'presence'},
#  {'id': 14784, 'prediction': 'presence'},
#  {'id': 65111, 'prediction': 'presence'},
#  {'id': 92210, 'prediction': 'presence'},
#  {'id': 44419, 'prediction': 'presence'},
#  {'id': 32566, 'prediction': 'presence'},
#  {'id': 94740, 'prediction': 'presence'},
#  {'id': 99039, 'prediction': 'absence'},
#  {'id': 55847, 'prediction': 'absence'},
#  {'id': 19719, 'prediction': 'absence'},
#  {'id': 92914, 'prediction': 'presence'},
#  {'id': 58006, 'prediction': 'presence'},
#  {'id': 93880, 'prediction': 'absence'},
#  {'id': 68639, 'prediction': 'presence'},
#  {'id': 96357, 'prediction': 'presence'},
#  {'id': 17222, 'prediction': 'presence'},
#  {'id': 56524, 'prediction': 'presence'},
#  {'id': 34266, 'prediction': 'presence'},
#  {'id': 44485, 'prediction': 'presence'},
#  {'id': 70138, 'prediction': 'presence'},
#  {'id': 4476, 'prediction': 'presence'},
#  {'id': 77056, 'prediction': 'presence'},
#  {'id': 89248, 'prediction': 'presence'},
#  {'id': 47934, 'prediction': 'absence'},
#  {'id': 11998, 'prediction': 'presence'},
#  {'id': 10887, 'prediction': 'presence'},
#  {'id': 56645, 'prediction': 'presence'},
#  {'id': 16425, 'prediction': 'presence'},
#  {'id': 96805, 'prediction': 'presence'},
#  {'id': 53212, 'prediction': 'absence'},
#  {'id': 68120, 'prediction': 'presence'},
#  {'id': 65289, 'prediction': 'absence'},
#  {'id': 85749, 'prediction': 'presence'},
#  {'id': 47814, 'prediction': 'presence'},
#  {'id': 29776, 'prediction': 'presence'},
#  {'id': 19885, 'prediction': 'presence'},
#  {'id': 94354, 'prediction': 'presence'},
#  {'id': 96887, 'prediction': 'absence'},
#  {'id': 89099, 'prediction': 'presence'},
#  {'id': 98773, 'prediction': 'absence'},
#  {'id': 40618, 'prediction': 'absence'},
#  {'id': 23119, 'prediction': 'absence'},
#  {'id': 56176, 'prediction': 'presence'},
#  {'id': 17111, 'prediction': 'presence'},
#  {'id': 79289, 'prediction': 'presence'},
#  {'id': 56545, 'prediction': 'presence'},
#  {'id': 20854, 'prediction': 'presence'},
#  {'id': 56006, 'prediction': 'presence'},
#  {'id': 31121, 'prediction': 'presence'},
#  {'id': 73965, 'prediction': 'presence'},
#  {'id': 91126, 'prediction': 'presence'},
#  {'id': 35404, 'prediction': 'absence'},
#  {'id': 74700, 'prediction': 'presence'},
#  {'id': 55420, 'prediction': 'presence'},
#  {'id': 36749, 'prediction': 'presence'},
#  {'id': 59063, 'prediction': 'presence'},
#  {'id': 24139, 'prediction': 'presence'},
#  {'id': 44315, 'prediction': 'presence'},
#  {'id': 96956, 'prediction': 'presence'},
#  {'id': 89061, 'prediction': 'absence'},
#  {'id': 17554, 'prediction': 'presence'},
#  {'id': 49334, 'prediction': 'presence'},
#  {'id': 73581, 'prediction': 'absence'},
#  {'id': 72334, 'prediction': 'presence'},
#  {'id': 12390, 'prediction': 'presence'},
#  {'id': 13715, 'prediction': 'presence'},
#  {'id': 47623, 'prediction': 'presence'},
#  {'id': 75139, 'prediction': 'presence'},
#  {'id': 1621, 'prediction': 'presence'},
#  {'id': 78457, 'prediction': 'absence'},
#  {'id': 22190, 'prediction': 'absence'},
#  {'id': 53174, 'prediction': 'presence'},
#  {'id': 70965, 'prediction': 'presence'},
#  {'id': 27257, 'prediction': 'presence'},
#  {'id': 91761, 'prediction': 'presence'},
#  {'id': 22246, 'prediction': 'presence'},
#  {'id': 62297, 'prediction': 'absence'},
#  {'id': 66604, 'prediction': 'presence'},
#  {'id': 56445, 'prediction': 'presence'},
#  {'id': 38847, 'prediction': 'presence'},
#  {'id': 77590, 'prediction': 'presence'},
#  {'id': 46420, 'prediction': 'absence'},
#  {'id': 3379, 'prediction': 'presence'},
#  {'id': 22093, 'prediction': 'absence'},
#  {'id': 51537, 'prediction': 'presence'},
#  {'id': 53008, 'prediction': 'presence'},
#  {'id': 3220, 'prediction': 'presence'},
#  {'id': 38264, 'prediction': 'presence'},
#  {'id': 93147, 'prediction': 'presence'},
#  {'id': 98183, 'prediction': 'absence'},
#  {'id': 46607, 'prediction': 'absence'},
#  {'id': 23852, 'prediction': 'presence'},
#  {'id': 26051, 'prediction': 'presence'},
#  {'id': 58592, 'prediction': 'presence'},
#  {'id': 98522, 'prediction': 'presence'},
#  {'id': 25493, 'prediction': 'absence'},
#  {'id': 42920, 'prediction': 'presence'},
#  {'id': 98398, 'prediction': 'presence'},
#  {'id': 73725, 'prediction': 'absence'},
#  {'id': 53760, 'prediction': 'presence'},
#  {'id': 35392, 'prediction': 'absence'},
#  {'id': 64583, 'prediction': 'presence'},
#  {'id': 96220, 'prediction': 'presence'},
#  {'id': 44325, 'prediction': 'presence'},
#  {'id': 6657, 'prediction': 'presence'},
#  {'id': 84433, 'prediction': 'presence'},
#  {'id': 43308, 'prediction': 'absence'},
#  {'id': 89438, 'prediction': 'presence'},
#  {'id': 35116, 'prediction': 'presence'},
#  {'id': 62571, 'prediction': 'presence'},
#  {'id': 72916, 'prediction': 'absence'},
#  {'id': 17454, 'prediction': 'presence'},
#  {'id': 93357, 'prediction': 'presence'},
#  {'id': 84123, 'prediction': 'absence'},
#  {'id': 98561, 'prediction': 'presence'},
#  {'id': 25207, 'prediction': 'presence'},
#  {'id': 8744, 'prediction': 'presence'},
#  {'id': 76357, 'prediction': 'presence'},
#  {'id': 57764, 'prediction': 'absence'},
#  {'id': 69133, 'prediction': 'presence'},
#  {'id': 76003, 'prediction': 'presence'},
#  {'id': 24983, 'prediction': 'presence'},
#  {'id': 21835, 'prediction': 'absence'},
#  {'id': 45280, 'prediction': 'presence'},
#  {'id': 16465, 'prediction': 'presence'},
#  {'id': 59247, 'prediction': 'absence'},
#  {'id': 29492, 'prediction': 'presence'},
#  {'id': 29850, 'prediction': 'presence'},
#  {'id': 59251, 'prediction': 'absence'},
#  {'id': 43840, 'prediction': 'presence'},
#  {'id': 45217, 'prediction': 'presence'},
#  {'id': 26773, 'prediction': 'absence'},
#  {'id': 36370, 'prediction': 'presence'},
#  {'id': 37784, 'prediction': 'presence'},
#  {'id': 62130, 'prediction': 'absence'},
#  {'id': 97346, 'prediction': 'presence'},
#  {'id': 80218, 'prediction': 'presence'},
#  {'id': 42643, 'prediction': 'absence'},
#  {'id': 54228, 'prediction': 'absence'},
#  {'id': 63133, 'prediction': 'presence'},
#  {'id': 42418, 'prediction': 'presence'},
#  {'id': 82095, 'prediction': 'presence'},
#  {'id': 98185, 'prediction': 'presence'},
#  {'id': 60159, 'prediction': 'presence'},
#  {'id': 19284, 'prediction': 'absence'},
#  {'id': 34963, 'prediction': 'presence'},
#  {'id': 61469, 'prediction': 'presence'},
#  {'id': 31991, 'prediction': 'presence'},
#  {'id': 51945, 'prediction': 'presence'},
#  {'id': 14451, 'prediction': 'presence'},
#  {'id': 89019, 'prediction': 'presence'},
#  {'id': 42572, 'prediction': 'presence'},
#  {'id': 2242, 'prediction': 'presence'},
#  {'id': 65363, 'prediction': 'presence'},
#  {'id': 25030, 'prediction': 'presence'},
#  {'id': 27067, 'prediction': 'presence'},
#  {'id': 90231, 'prediction': 'presence'},
#  {'id': 16884, 'prediction': 'presence'},
#  {'id': 62552, 'prediction': 'presence'},
#  {'id': 2746, 'prediction': 'presence'},
#  {'id': 42237, 'prediction': 'presence'},
#  {'id': 5875, 'prediction': 'absence'},
#  {'id': 56387, 'prediction': 'presence'},
#  {'id': 14804, 'prediction': 'absence'},
#  {'id': 4062, 'prediction': 'presence'},
#  {'id': 75755, 'prediction': 'presence'},
#  {'id': 66827, 'prediction': 'presence'},
#  {'id': 44459, 'prediction': 'presence'},
#  {'id': 71523, 'prediction': 'presence'},
#  {'id': 77668, 'prediction': 'presence'},
#  {'id': 44545, 'prediction': 'absence'},
#  {'id': 83539, 'prediction': 'absence'},
#  {'id': 37842, 'prediction': 'presence'},
#  {'id': 14891, 'prediction': 'presence'},
#  {'id': 653, 'prediction': 'presence'},
#  {'id': 22839, 'prediction': 'presence'},
#  {'id': 4276, 'prediction': 'presence'},
#  {'id': 83696, 'prediction': 'absence'},
#  {'id': 33453, 'prediction': 'presence'},
#  {'id': 80727, 'prediction': 'presence'},
#  {'id': 15845, 'prediction': 'presence'},
#  {'id': 48909, 'prediction': 'presence'},
#  {'id': 4888, 'prediction': 'presence'},
#  {'id': 7902, 'prediction': 'presence'},
#  {'id': 69429, 'prediction': 'presence'},
#  {'id': 17262, 'prediction': 'presence'},
#  {'id': 8220, 'prediction': 'presence'},
#  {'id': 56132, 'prediction': 'presence'},
#  {'id': 95491, 'prediction': 'presence'},
#  {'id': 61564, 'prediction': 'presence'},
#  {'id': 7863, 'prediction': 'presence'},
#  {'id': 91202, 'prediction': 'absence'},
#  {'id': 88507, 'prediction': 'absence'},
#  {'id': 4666, 'prediction': 'presence'},
#  {'id': 61939, 'prediction': 'presence'},
#  {'id': 80320, 'prediction': 'presence'},
#  {'id': 4430, 'prediction': 'presence'},
#  {'id': 18390, 'prediction': 'presence'},
#  {'id': 58248, 'prediction': 'absence'},
#  {'id': 60910, 'prediction': 'absence'},
#  {'id': 60199, 'prediction': 'presence'},
#  {'id': 10904, 'prediction': 'presence'},
#  {'id': 6460, 'prediction': 'absence'},
#  {'id': 35796, 'prediction': 'absence'},
#  {'id': 38445, 'prediction': 'presence'},
#  {'id': 1160, 'prediction': 'presence'},
#  {'id': 88790, 'prediction': 'absence'},
#  {'id': 8819, 'prediction': 'presence'},
#  {'id': 67367, 'prediction': 'presence'},
#  {'id': 6108, 'prediction': 'presence'},
#  {'id': 36150, 'prediction': 'absence'},
#  {'id': 10378, 'prediction': 'absence'},
#  {'id': 39257, 'prediction': 'presence'},
#  {'id': 75140, 'prediction': 'presence'},
#  {'id': 65561, 'prediction': 'presence'},
#  {'id': 16083, 'prediction': 'presence'},
#  {'id': 17504, 'prediction': 'presence'},
#  {'id': 47903, 'prediction': 'presence'},
#  {'id': 97553, 'prediction': 'presence'},
#  {'id': 49196, 'prediction': 'presence'},
#  {'id': 26548, 'prediction': 'presence'},
#  {'id': 15109, 'prediction': 'presence'},
#  {'id': 90461, 'prediction': 'presence'},
#  {'id': 53501, 'prediction': 'presence'},
#  {'id': 95160, 'prediction': 'presence'},
#  {'id': 39724, 'prediction': 'absence'},
#  {'id': 16727, 'prediction': 'presence'},
#  {'id': 52767, 'prediction': 'absence'},
#  {'id': 87964, 'prediction': 'presence'},
#  {'id': 13734, 'prediction': 'presence'},
#  {'id': 40999, 'prediction': 'presence'},
#  {'id': 13918, 'prediction': 'presence'},
#  {'id': 57559, 'prediction': 'presence'},
#  {'id': 88897, 'prediction': 'presence'},
#  {'id': 67570, 'prediction': 'presence'},
#  {'id': 93141, 'prediction': 'presence'},
#  {'id': 34574, 'prediction': 'presence'},
#  {'id': 6527, 'prediction': 'presence'},
#  {'id': 91413, 'prediction': 'presence'},
#  {'id': 13500, 'prediction': 'presence'},
#  {'id': 44507, 'prediction': 'presence'},
#  {'id': 48831, 'prediction': 'presence'},
#  {'id': 31188, 'prediction': 'presence'},
#  {'id': 76941, 'prediction': 'presence'},
#  {'id': 82993, 'prediction': 'presence'},
#  {'id': 44451, 'prediction': 'presence'},
#  {'id': 32768, 'prediction': 'absence'},
#  {'id': 62288, 'prediction': 'presence'},
#  {'id': 3643, 'prediction': 'presence'},
#  {'id': 93215, 'prediction': 'presence'},
#  {'id': 41074, 'prediction': 'presence'},
#  {'id': 31700, 'prediction': 'presence'},
#  {'id': 83186, 'prediction': 'presence'},
#  {'id': 30724, 'prediction': 'absence'},
#  {'id': 75810, 'prediction': 'presence'},
#  {'id': 60770, 'prediction': 'presence'},
#  {'id': 94497, 'prediction': 'presence'},
#  {'id': 10133, 'prediction': 'presence'},
#  {'id': 87990, 'prediction': 'presence'},
#  {'id': 42697, 'prediction': 'presence'},
#  {'id': 44999, 'prediction': 'presence'},
#  {'id': 8378, 'prediction': 'presence'},
#  {'id': 40420, 'prediction': 'presence'},
#  {'id': 81724, 'prediction': 'absence'},
#  {'id': 87061, 'prediction': 'absence'},
#  {'id': 45603, 'prediction': 'absence'},
#  {'id': 35691, 'prediction': 'presence'},
#  {'id': 75333, 'prediction': 'presence'},
#  {'id': 46983, 'prediction': 'absence'},
#  {'id': 88171, 'prediction': 'presence'},
#  {'id': 91339, 'prediction': 'absence'},
#  {'id': 74544, 'prediction': 'presence'},
#  {'id': 33630, 'prediction': 'presence'},
#  {'id': 16739, 'prediction': 'absence'},
#  {'id': 85037, 'prediction': 'presence'},
#  {'id': 95635, 'prediction': 'presence'},
#  {'id': 56850, 'prediction': 'presence'},
#  {'id': 9032, 'prediction': 'presence'},
#  {'id': 22759, 'prediction': 'presence'},
#  {'id': 26042, 'prediction': 'presence'},
#  {'id': 37144, 'prediction': 'absence'},
#  {'id': 12225, 'prediction': 'presence'},
#  {'id': 93058, 'prediction': 'presence'},
#  {'id': 85725, 'prediction': 'presence'},
#  {'id': 93014, 'prediction': 'presence'},
#  {'id': 72389, 'prediction': 'presence'},
#  {'id': 37599, 'prediction': 'absence'},
#  {'id': 12547, 'prediction': 'presence'},
#  {'id': 41582, 'prediction': 'presence'},
#  {'id': 87119, 'prediction': 'absence'},
#  {'id': 82827, 'prediction': 'absence'},
#  {'id': 74222, 'prediction': 'absence'},
#  {'id': 66550, 'prediction': 'absence'},
#  {'id': 41115, 'prediction': 'presence'},
#  {'id': 40370, 'prediction': 'absence'},
#  {'id': 34498, 'prediction': 'presence'},
#  {'id': 39627, 'prediction': 'presence'},
#  {'id': 43132, 'prediction': 'absence'},
#  {'id': 76218, 'prediction': 'presence'},
#  {'id': 1555, 'prediction': 'absence'},
#  {'id': 3660, 'prediction': 'presence'},
#  {'id': 54966, 'prediction': 'presence'},
#  {'id': 72002, 'prediction': 'presence'},
#  {'id': 49058, 'prediction': 'presence'},
#  {'id': 32842, 'prediction': 'presence'},
#  {'id': 21273, 'prediction': 'presence'},
#  {'id': 11386, 'prediction': 'presence'},
#  {'id': 54552, 'prediction': 'presence'},
#  {'id': 89474, 'prediction': 'absence'},
#  {'id': 2813, 'prediction': 'presence'},
#  {'id': 5378, 'prediction': 'presence'},
#  {'id': 91203, 'prediction': 'presence'},
#  {'id': 57052, 'prediction': 'absence'},
#  {'id': 91557, 'prediction': 'presence'},
#  {'id': 11211, 'prediction': 'presence'},
#  {'id': 21100, 'prediction': 'presence'},
#  {'id': 90234, 'prediction': 'absence'},
#  {'id': 95396, 'prediction': 'presence'},
#  {'id': 38785, 'prediction': 'absence'},
#  {'id': 36863, 'prediction': 'presence'},
#  {'id': 31486, 'prediction': 'presence'},
#  {'id': 22387, 'prediction': 'absence'},
#  {'id': 98232, 'prediction': 'presence'},
#  {'id': 91319, 'prediction': 'presence'},
#  {'id': 43556, 'prediction': 'presence'},
#  {'id': 52664, 'prediction': 'presence'},
#  {'id': 44576, 'prediction': 'presence'},
#  {'id': 93326, 'prediction': 'absence'},
#  {'id': 25504, 'prediction': 'presence'},
#  {'id': 20254, 'prediction': 'presence'},
#  {'id': 12492, 'prediction': 'presence'},
#  {'id': 4246, 'prediction': 'presence'},
#  {'id': 38927, 'prediction': 'presence'},
#  {'id': 43807, 'prediction': 'presence'},
#  {'id': 85534, 'prediction': 'presence'},
#  {'id': 86071, 'prediction': 'presence'},
#  {'id': 72169, 'prediction': 'presence'},
#  {'id': 86574, 'prediction': 'presence'},
#  {'id': 49379, 'prediction': 'presence'},
#  {'id': 58970, 'prediction': 'presence'},
#  {'id': 22609, 'prediction': 'presence'},
#  {'id': 99391, 'prediction': 'absence'},
#  {'id': 36320, 'prediction': 'absence'},
#  {'id': 86710, 'prediction': 'presence'},
#  {'id': 88635, 'prediction': 'presence'},
#  {'id': 29248, 'prediction': 'presence'},
#  {'id': 88779, 'prediction': 'absence'},
#  {'id': 72487, 'prediction': 'presence'},
#  {'id': 88144, 'prediction': 'absence'},
#  {'id': 13174, 'prediction': 'presence'},
#  {'id': 39432, 'prediction': 'presence'},
#  {'id': 73605, 'prediction': 'presence'},
#  {'id': 36674, 'prediction': 'presence'},
#  {'id': 81453, 'prediction': 'presence'},
#  {'id': 13408, 'prediction': 'presence'},
#  {'id': 19983, 'prediction': 'presence'},
#  {'id': 51624, 'prediction': 'presence'},
#  {'id': 38213, 'prediction': 'presence'},
#  {'id': 31607, 'prediction': 'presence'},
#  {'id': 31197, 'prediction': 'presence'},
#  {'id': 91236, 'prediction': 'presence'},
#  {'id': 72927, 'prediction': 'presence'},
#  {'id': 94008, 'prediction': 'presence'},
#  {'id': 58131, 'prediction': 'presence'},
#  {'id': 97749, 'prediction': 'presence'},
#  {'id': 47095, 'prediction': 'presence'},
#  {'id': 98746, 'prediction': 'presence'},
#  {'id': 26509, 'prediction': 'presence'},
#  {'id': 30519, 'prediction': 'presence'},
#  {'id': 57142, 'prediction': 'presence'},
#  {'id': 83042, 'prediction': 'presence'},
#  {'id': 38335, 'prediction': 'presence'},
#  {'id': 32869, 'prediction': 'presence'},
#  {'id': 99339, 'prediction': 'presence'},
#  {'id': 25329, 'prediction': 'absence'},
#  {'id': 69381, 'prediction': 'presence'},
#  {'id': 20563, 'prediction': 'presence'},
#  {'id': 95121, 'prediction': 'presence'},
#  {'id': 69099, 'prediction': 'presence'},
#  {'id': 43142, 'prediction': 'presence'},
#  {'id': 33742, 'prediction': 'absence'},
#  {'id': 35801, 'prediction': 'presence'},
#  {'id': 57561, 'prediction': 'absence'},
#  {'id': 92185, 'prediction': 'absence'},
#  {'id': 27107, 'prediction': 'presence'},
#  {'id': 54157, 'prediction': 'presence'},
#  {'id': 17247, 'prediction': 'presence'},
#  {'id': 89519, 'prediction': 'presence'},
#  {'id': 76444, 'prediction': 'presence'},
#  {'id': 88136, 'prediction': 'presence'},
#  {'id': 37483, 'prediction': 'presence'},
#  {'id': 83001, 'prediction': 'presence'},
#  {'id': 40286, 'prediction': 'presence'},
#  {'id': 3254, 'prediction': 'absence'},
#  {'id': 27534, 'prediction': 'absence'},
#  {'id': 2392, 'prediction': 'presence'},
#  {'id': 81219, 'prediction': 'absence'},
#  {'id': 11874, 'prediction': 'presence'},
#  {'id': 93615, 'prediction': 'presence'},
#  {'id': 71417, 'prediction': 'presence'},
#  {'id': 9142, 'prediction': 'presence'},
#  {'id': 33046, 'prediction': 'presence'},
#  {'id': 31342, 'prediction': 'presence'},
#  {'id': 31962, 'prediction': 'absence'},
#  {'id': 81341, 'prediction': 'presence'},
#  {'id': 5368, 'prediction': 'absence'},
#  {'id': 39430, 'prediction': 'presence'},
#  {'id': 74405, 'prediction': 'presence'},
#  {'id': 72997, 'prediction': 'presence'},
#  {'id': 11484, 'prediction': 'presence'},
#  {'id': 683, 'prediction': 'presence'},
#  {'id': 19496, 'prediction': 'presence'},
#  {'id': 81518, 'prediction': 'presence'},
#  {'id': 14244, 'prediction': 'presence'},
#  {'id': 41637, 'prediction': 'absence'},
#  {'id': 48399, 'prediction': 'presence'},
#  {'id': 80934, 'prediction': 'absence'},
#  {'id': 56401, 'prediction': 'presence'},
#  {'id': 85647, 'prediction': 'presence'},
#  {'id': 16514, 'prediction': 'presence'},
#  {'id': 86761, 'prediction': 'absence'},
#  {'id': 12983, 'prediction': 'presence'},
#  {'id': 10290, 'prediction': 'presence'},
#  {'id': 82567, 'prediction': 'presence'},
#  {'id': 76071, 'prediction': 'presence'},
#  {'id': 51794, 'prediction': 'presence'},
#  {'id': 85879, 'prediction': 'presence'},
#  {'id': 81226, 'prediction': 'presence'},
#  {'id': 98925, 'prediction': 'absence'},
#  {'id': 72621, 'prediction': 'absence'},
#  {'id': 38784, 'prediction': 'presence'},
#  {'id': 62105, 'prediction': 'presence'},
#  {'id': 30633, 'prediction': 'presence'},
#  {'id': 26026, 'prediction': 'presence'},
#  {'id': 44113, 'prediction': 'absence'},
#  {'id': 90847, 'prediction': 'absence'},
#  {'id': 79439, 'prediction': 'absence'},
#  ...]

# %%
try: 
  user_choice = int(input("Enter the id"))
except Exception:
  print('Invalid input:Please enter the valid input')
  user_choice = int(input("Enter the id"))
def predict_result(user_choice):
  for result in results:
    if (result['id'] == user_choice):
      return result
print("ID not found")
result = predict_result(user_choice)
result

# %% [markdown]
# ## **Prediction stored in MongoDBNoSQL database.**

# %%
# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")  # Replace with your MongoDB connection string
db = client["heart_disease_database"]  # Replace with your database name
collection = db["prediction_results"]  # Replace with your desired collection name

# Insert results into the MongoDB collection
collection.insert_one(result)

# Close the MongoDB connection
client.close()
print("Predictions saved in MongoDB.")
# Out:
# Predictions saved in MongoDB.

# %% [markdown]
# ## *Gannet Optimization Algorithm (GOA)*

# %%
# Problem-specific parameters
num_variables = 10  # Number of optimization variables
lower_bound = -10  # Lower bound of variables
upper_bound = 10   # Upper bound of variables

# Algorithm parameters
num_gannets = 50    # Number of gannets (population size)
max_iterations = 100  # Maximum number of iterations
a_max = 2            # Maximum value for acceleration coefficient a
# Initialize gannet positions
gannet_positions = np.random.uniform(low=lower_bound, high=upper_bound, size=(num_gannets, num_variables))
best_solution = None
best_fitness = np.inf
def calculate_fitness(positions):
    # Calculate fitness values for each gannet's position
    fitness_values = np.sum(positions ** 2, axis=1)
    return fitness_values
for iteration in range(max_iterations):
    # Calculate fitness values for each gannet
    fitness_values = calculate_fitness(gannet_positions)  

    # Update the best solution
    min_fitness_index = np.argmin(fitness_values)
    if fitness_values[min_fitness_index] < best_fitness:
        best_fitness = fitness_values[min_fitness_index]
        best_solution = gannet_positions[min_fitness_index]

    # Calculate a for each gannet
    a_values = a_max - iteration * ((a_max - 1) / max_iterations)

    # Update gannet positions using their acceleration
    for i in range(num_gannets):
        for j in range(num_variables):
            r1 = np.random.random()
            r2 = np.random.random()
            r3 = np.random.random()
            C1 = 2 * r3
            D = np.abs(C1 * best_solution[j] - gannet_positions[i, j])
            gannet_positions[i, j] = (
                best_solution[j] - a_values * D * np.exp(-0.5 * (iteration / max_iterations))
                * np.cos(2 * np.pi * r2)
            )
            gannet_positions[i, j] = np.clip(gannet_positions[i, j], lower_bound, upper_bound)

y_preds = model.predict(X_test)
# Convert predicted probabilities to class labels
pred_labels = np.argmax(y_preds, axis=1)
# Convert true labels to class labels
true_labels = np.argmax(y_test, axis=1)
print("Best solution:", best_solution)
print("Best fitness:", best_fitness)
# Out:
# 547/547 [==============================] - 1s 1ms/step
# Best solution: [-5.97473312e-08  9.23114844e-09  6.21194902e-08  4.30941335e-08
#   1.61444824e-08 -6.69460033e-09 -1.59353292e-08  7.86541929e-08
#   4.73096226e-08 -6.49997958e-08]
# Best fitness: 2.6174985351895094e-14

# %% [markdown]
# ## *Result*

# %%
# Calculate accuracy
accuracy = accuracy_score(true_labels, pred_labels)
print("Accuracy:", accuracy )
print()
print("Error rate:" , 1-accuracy)
print()
# Calculate precision
precision = precision_score(true_labels, pred_labels)
print("Precision:", precision)
print()
# Calculate recall
recall = recall_score(true_labels, pred_labels)
print("Recall:", recall)
print()
conf_matrix=confusion_matrix(true_labels, pred_labels)
# True Negative (TN), False Positive (FP), False Negative (FN), True Positive (TP)
TN, FN, FP, TP = conf_matrix.ravel()
# Calculate specificity
specificity = TN / (TN + FP)
# Calculate F1-score
f1 = f1_score(true_labels, pred_labels)
# Specify training parameters
batch_size = 50
epochs = 15

# Calculate estimated computation time
start_time = time.time()
iterations_per_epoch = X_train.shape[0] // batch_size
total_iterations = iterations_per_epoch * epochs
time_per_pass = 0.006  # Assumption: 10 ms per forward-backward pass

estimated_computation_time = time_per_pass * total_iterations
end_time = time.time()

print(f"Estimated Computation Time: {estimated_computation_time:.2f} seconds")
print("F1-score:", f1)
print()
print("Specificity :",specificity)
print()
print("ROC :",roc_auc_score(true_labels, pred_labels))
print()
print("confusion_matrix")
print(confusion_matrix(true_labels, pred_labels))
print()
print("classification_report")
print(classification_report(true_labels, pred_labels))
# Out:
# Accuracy: 0.9965714285714286
#
# Error rate: 0.0034285714285714475
#
# Precision: 0.995823600198202
#
# Recall: 0.9999289217428389
#
# F1-score: 0.9978720385870337
#
# Specificity : 0.9997035280166024
#
# ROC : 0.9913663845088428
#
# confusion_matrix
# [[ 3372    59]
#  [    1 14068]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      3431
#            1       1.00      1.00      1.00     14069
#
#     accuracy                           1.00     17500
#    macro avg       1.00      0.99      0.99     17500
# weighted avg       1.00      1.00      1.00     17500
